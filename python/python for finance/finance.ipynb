# %% [markdown]
#  a sample python program

# %%
#the future value of an investment

import numpy_financial as npf 


res = npf.fv(rate=0.08, nper=5, pmt=0, pv=-1000)

print(res)
# Out:
# 1469.3280768000006

# %%
#monthly mortgage payment - pagamento mensal da hipoteca

new = npf.pmt(rate=0.10/12, nper=5*12, pv=0, fv=50000)

print(new)
# Out:
# -645.6855688967499

# %%
# IRR - internal rate of return (taxa interna de retorno)

cf1 = [-50000, 10000, 25000, 25000, 35000, 42000]
cf2 = [-30000, 10000, 13000, 18000, 25000, 20000]

print("Option 1: ", npf.irr(cf1))
print("Option 2: ", npf.irr(cf2))
# Out:
# Option 1:  0.3605982754620043
# Option 2:  0.4094208743397143

# %%
# Let's continue with our Bitcoin project!

# You decide to start a Bitcoin mining business in January of 2017. You make an initial investment of $500K to buy the required mining hardware.
# Each year the hardware can mine 10 bitcoins, so your first return will come on January 1, 2018.

# Task
# Calculate the return for each year and output the IRR of the project.

# Hint
# Create an array with the initial investment as the first element (with a negative value), followed by the cost of 10 bitcoins per year -- multiply the values of the given array by 10 and accordingly add them to the list you created, placing them after the investment value.

# Expected result
# 0.07297215919675315 

# Use npf.irr() function to calculate the IRR.

import numpy as np
import numpy_financial as npf

#price for 2018-2021
bitcoin = [3869.47, 7188.46, 22203.31, 29391.78]

cashflow = [-500000]
for price in bitcoin:
    cashflow.append(price*10)
print(npf.irr(cashflow))
# Out:
# 0.07297215919675315

# %%
# IRR-bitcoin

import numpy as np

#price per bitcoin for 2018-2021
bitcoin = [3869.47, 7188.46, 22203.31, 29391.78]

#let´s say we´re mining 10 bitcoins per year
n= 10

#time value of money where 500k is the initial investment
tvm = np.array([-500000, bitcoin[0]*n, bitcoin[1]*n, bitcoin[2]*n, bitcoin[3]*n])

#print internal rate of return
print("internal rate of return")
print(npf.irr(tvm))
# Out:
# internal rate of return
# 0.07297215919675315

# %%
import matplotlib.pyplot as plt


plt.plot(bitcoin)

plt.savefig('plot.png')

# %%
# pandas

import pandas as pd

prices = [42.8, 102.03, 240.38, 80.9]

s = pd.Series(prices)
print(s)
# Out:
# 0     42.80
# 1    102.03
# 2    240.38
# 3     80.90
# dtype: float64

# %%
print(s.describe())
# Out:
# count      4.000000
# mean     116.527500
# std       86.129132
# min       42.800000
# 25%       71.375000
# 50%       91.465000
# 75%      136.617500
# max      240.380000
# dtype: float64

# %%
#DataFrame

data = {
  'date': ['2021-06-10', '2021-06-11', '2021-06-12', '2021-06-13'],
  'prices': [42.8, 102.03, 240.38, 80.9]
}
df = pd.DataFrame(data)
print(df)
# Out:
#          date  prices
# 0  2021-06-10   42.80
# 1  2021-06-11  102.03
# 2  2021-06-12  240.38
# 3  2021-06-13   80.90

# %%
#web scraping

data = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
df = data[0]

df = df[['Symbol', 'Security']]
print(df)
# Out:
#     Symbol              Security
# 0      MMM                    3M
# 1      AOS           A. O. Smith
# 2      ABT                Abbott
# 3     ABBV                AbbVie
# 4      ACN             Accenture
# ..     ...                   ...
# 498    YUM           Yum! Brands
# 499   ZBRA    Zebra Technologies
# 500    ZBH         Zimmer Biomet
# 501   ZION  Zions Bancorporation
# 502    ZTS                Zoetis
#
# [503 rows x 2 columns]

# %%
df = data[0]
df = df[df['Security'] == 'Apple']
print(df)
# Out:
# Empty DataFrame
# Columns: [Symbol, Security, GICS Sector, GICS Sub-Industry, Headquarters Location, Date added, CIK, Founded]
# Index: []

# %%
# scraping yahoo finance

import pandas as pd
import requests

url_link = 'https://finance.yahoo.com/quote/TSLA/profile'
r = requests.get(url_link,headers ={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'})

data = pd.read_html(r.text)
print(data[0])
# Out:
# C:\Users\Risonaldo\AppData\Local\Temp\ipykernel_9452\977961948.py:9: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data = pd.read_html(r.text)
#                          Name  \
# 0            Mr. Elon R. Musk
# 1       Mr. Andrew D. Baglino
# 2          Mr. Vaibhav Taneja
# 3           Mr. Martin Viecha
# 4                Brian Scelfo
# 5  Mr. Jeffrey Brian Straubel
# 6    Mr. Franz von Holzhausen
# 7            Mr. Xiaotong Zhu
# 8             Mr. John Walker
# 9            Mr. Peter Bannon
#
#                                                Title      Pay Exercised  \
# 0                Technoking of Tesla, CEO & Director      NaN       NaN
# 1  Senior Vice President of Powertrain & Energy E...     303k    33.87M
# 2  CFO, Corporate Controller & Chief Accounting O...      NaN       NaN
# 3             Senior Director for Investor Relations      NaN       NaN
# 4           Senior Director of Corporate Development      NaN       NaN
# 5                               Independent Director  250.56k     9.41M
# 6                                     Chief Designer      NaN       NaN
# 7                Senior Vice President of Automotive      NaN       NaN
# 8            Vice President of Sales - North America  121.55k       NaN
# 9                                     Chip Architect      NaN       NaN
#
#    Year Born
# 0     1972.0
# 1     1981.0
# 2     1978.0
# 3        NaN
# 4        NaN
# 5     1976.0
# 6        NaN
# 7     1980.0
# 8     1963.0
# 9        NaN

# %%
# access company Data

import yfinance as yf

data = yf.Ticker("KO")
print(data.major_holders)
# Out:
# Breakdown                          Value
# insidersPercentHeld              0.00663
# institutionsPercentHeld          0.71715
# institutionsFloatPercentHeld     0.72194
# institutionsCount             3641.00000

# %%
print(data.institutional_holders)
# Out:
#   Date Reported                                      Holder  pctHeld  \
# 0    2023-06-30                     Berkshire Hathaway, Inc   0.0925
# 1    2023-06-30                          Vanguard Group Inc   0.0855
# 2    2023-06-30                              Blackrock Inc.   0.0700
# 3    2023-06-30                    State Street Corporation   0.0396
# 4    2023-06-30               Geode Capital Management, LLC   0.0183
# 5    2023-06-30                   JP Morgan Chase & Company   0.0183
# 6    2023-06-30                              Morgan Stanley   0.0182
# 7    2023-06-30                                    FMR, LLC   0.0172
# 8    2023-06-30  Charles Schwab Investment Management, Inc.   0.0140
# 9    2022-12-31           Norges Bank Investment Management   0.0107
#
#       Shares        Value
# 0  400000000  24088000000
# 1  369884918  22274469761
# 2  302588568  18221883564
# 3  171246926  10312489883
# 4   79165884   4767369534
# 5   78941015   4753827923
# 6   78497937   4727145766
# 7   74442533   4482929337
# 8   60674352   3653809477
# 9   46176945   2937315471

# %%
#recomendation

data = yf.Ticker("MMM")

x = data.recommendations
#x = x[x.index > '2023-01-02']

print(x)
# Out:
#   period  strongBuy  buy  hold  sell  strongSell
# 0     0m          4    1     7     3           0
# 1    -1m          0    0    16     2           0
# 2    -2m          0    0    15     3           0
# 3    -3m          0    1    15     5           2

# %%
# ROE

def RoE(ticker):
    data = yf.Ticker(ticker)
    roe = data.info['returnOnEquity']
    name = data.info['shortName']
    print(name, ":", roe)
    
RoE('MMM')
RoE('T')
RoE('TXN')
RoE('ko')
# Out:
# 3M Company : -0.71075994
# AT&T Inc. : 0.13833
# Texas Instruments Incorporated : 0.41367
# Coca-Cola Company (The) : 0.41221002

# %%
data = yf.Ticker('MMM')
print(data.history(period='5d'))
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-01-22 00:00:00-05:00  108.500000  109.410004  107.400002  108.019997
# 2024-01-23 00:00:00-05:00  100.860001  100.860001   94.110001   96.099998
# 2024-01-24 00:00:00-05:00   96.639999   97.040001   92.730003   93.239998
# 2024-01-25 00:00:00-05:00   93.779999   96.279999   93.610001   95.980003
# 2024-01-26 00:00:00-05:00   96.220001   96.900002   95.790001   95.989998
#
#                              Volume  Dividends  Stock Splits
# Date
# 2024-01-22 00:00:00-05:00   4916100        0.0           0.0
# 2024-01-23 00:00:00-05:00  27210900        0.0           0.0
# 2024-01-24 00:00:00-05:00   9366600        0.0           0.0
# 2024-01-25 00:00:00-05:00   6122900        0.0           0.0
# 2024-01-26 00:00:00-05:00   3719700        0.0           0.0

# %%
x = data.history()['Close']
x.plot()
plt.savefig('plot.png')

# %%
data = yf.download("MMM TXN T KO", start='2023-01-01')

print(data['Close'])
# Out:
# [*********************100%%**********************]  4 of 4 completed
# Ticker             KO         MMM          T         TXN
# Date
# 2023-01-03  62.950001  122.470001  18.740000  163.210007
# 2023-01-04  62.919998  125.150002  19.139999  169.169998
# 2023-01-05  62.200001  122.959999  19.209999  166.929993
# 2023-01-06  63.400002  126.720001  19.530001  175.160004
# 2023-01-09  62.610001  126.790001  19.040001  176.679993
# ...               ...         ...        ...         ...
# 2024-01-22  59.570000  108.019997  16.799999  174.830002
# 2024-01-23  59.849998   96.099998  17.190001  174.339996
# 2024-01-24  58.910000   93.239998  16.680000  170.070007
# 2024-01-25  59.160000   95.980003  17.180000  167.419998
# 2024-01-26  59.369999   95.989998  17.290001  164.089996
#
# [268 rows x 4 columns]

# %%
data['Close'].plot()
plt.savefig('plot.png')

# %%
#bitcoin project - Ana vuckovic


import numpy as np
import numpy_financial as npf
import matplotlib.pyplot as plt
import yfinance as yf

data = yf.Ticker('BTC-USD')
x = data.history('1y')['Close']

#Daily returns
d = yf.download('BTC-USD',start = '2022-01-01')
#Percentage change
pc = d['Close'].pct_change()
#Volatility
annual = np.std(pc)*np.sqrt(252)*100
print("Risk: ",annual)
sharpe = (np.mean(pc)/np.std(pc))*np.sqrt(252)
print("Sharpe: ",sharpe)

num_of_btc = 1000/x[0]
btc = np.multiply(x,num_of_btc)
plt.plot(btc)
plt.savefig('plot.png')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\Risonaldo\AppData\Local\Temp\ipykernel_9452\2894208093.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   num_of_btc = 1000/x[0]
# Risk:  45.47931922421614
# Sharpe:  0.1326150333939778
